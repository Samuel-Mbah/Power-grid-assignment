# %%
import gymnasium as gym
import grid2op
from grid2op import gym_compat
from grid2op.Parameters import Parameters
from grid2op.Action import PlayableAction
from grid2op.Observation import CompleteObservation
from grid2op.Reward import L2RPNReward, N1Reward, CombinedScaledReward

from lightsim2grid import LightSimBackend
import numpy as np
from gymnasium.spaces import Box, Discrete

import matplotlib.pyplot as plt
from stable_baselines3 import DQN

import torch as th
import torch.nn as nn
from stable_baselines3.dqn.policies import DQNPolicy

# %%
import grid2op
print(grid2op.__version__)
# Out:
# 1.10.5

# %% [markdown]
# ### Baseline Environment

# %%
class Gym2OpEnvBaseline(gym.Env):
    def __init__(self):
        super().__init__()

        self._backend = LightSimBackend()
        self._env_name = "l2rpn_case14_sandbox"  # DO NOT CHANGE

        action_class = PlayableAction
        observation_class = CompleteObservation
        reward_class = CombinedScaledReward
     

        # DO NOT CHANGE Parameters
        p = Parameters()
        p.MAX_SUB_CHANGED = 4
        p.MAX_LINE_STATUS_CHANGED = 4

        # Make grid2op env
        self._g2op_env = grid2op.make(
            self._env_name,
            backend=self._backend,
            test=False,
            action_class=action_class,
            observation_class=observation_class,
            reward_class=reward_class,
            param=p,
         )

        # Set combined reward
        cr = self._g2op_env.get_reward_instance()
        cr.addReward("N1", N1Reward(), 1.0)
        cr.addReward("L2RPN", L2RPNReward(), 1.0)
        cr.initialize(self._g2op_env)
        self._g2op_env.change_reward(cr)

        self._gym_env = gym_compat.GymEnv(self._g2op_env)

        self.setup_observations()
        self.setup_actions()

    def setup_observations(self):
        # Flatten the observation space  ///Initial observations without any modifications
        sample_obs, _ = self._gym_env.reset()
        flat_obs = self.flatten_observation(sample_obs)
        obs_size = flat_obs.shape[0]
        self.observation_space = gym.spaces.Box(low=-np.inf, high=np.inf, shape=(obs_size,), dtype=np.float32)

     

    def setup_actions(self):
        self.available_actions = []

        # Get the action space from the Grid2Op environment
        action_space = self._g2op_env.action_space

        # Define discrete actions
        # Action 0: Do nothing
        no_op = action_space({})
        gym_no_op = self._gym_env.action_space.to_gym(no_op)
        self.available_actions.append(gym_no_op)

        # Action 1: Open line 0
        open_line_0 = action_space({"set_line_status": [(0, -1)]})
        gym_open_line_0 = self._gym_env.action_space.to_gym(open_line_0)
        self.available_actions.append(gym_open_line_0)

        # Action 2: Close line 0
        close_line_0 = action_space({"set_line_status": [(0, 1)]})
        gym_close_line_0 = self._gym_env.action_space.to_gym(close_line_0)
        self.available_actions.append(gym_close_line_0)

        # Update the action space to Discrete
        self.action_space = gym.spaces.Discrete(len(self.available_actions))


    def reset(self, seed=None):
        obs, info = self._gym_env.reset(seed=seed, options=None)
        obs = self.flatten_observation(obs)
        return obs, info

    def step(self, action):
        # Retrieve the Gym-formatted action
        gym_action = self.available_actions[action]

        # Pass the action to the environment
        obs, reward, terminated, truncated, info = self._gym_env.step(gym_action)
        obs = self.flatten_observation(obs)

        # Extract individual rewards
        reward_components = info.get('reward_detail', {})
        info['reward_components'] = reward_components
        
        return obs, reward, terminated, truncated, info

    def render(self):
        return self._gym_env.render()

    def flatten_observation(self, obs):
        obs_list = []
        for key in sorted(obs.keys()):
            obs_component = np.array(obs[key]).flatten()
            obs_list.append(obs_component)
        flat_obs = np.concatenate(obs_list).astype(np.float32)
        return flat_obs

# %% [markdown]
# - #### `Initialise` the Improved and Modified environment

# %%
class Gym2OpEnv(gym.Env):
    def __init__(self):
        super().__init__()

        self._backend = LightSimBackend()
        self._env_name = "l2rpn_case14_sandbox"  # DO NOT CHANGE

        action_class = PlayableAction
        observation_class = CompleteObservation
        reward_class = CombinedScaledReward
     

        # DO NOT CHANGE Parameters
        p = Parameters()
        p.MAX_SUB_CHANGED = 4
        p.MAX_LINE_STATUS_CHANGED = 4

        # Make grid2op env
        self._g2op_env = grid2op.make(
            self._env_name,
            backend=self._backend,
            test=False,
            action_class=action_class,
            observation_class=observation_class,
            reward_class=reward_class,
            param=p,
         )

        # Set combined reward
        cr = self._g2op_env.get_reward_instance()
        cr.addReward("N1", N1Reward(), 1.0)
        cr.addReward("L2RPN", L2RPNReward(), 1.0)
        cr.initialize(self._g2op_env)
        self._g2op_env.change_reward(cr)

        self._gym_env = gym_compat.GymEnv(self._g2op_env)

        self.relevantObservations = [
        "minute_of_hour"
        ,"gen_p"
        ,"gen_q"
        ,"gen_v"
        ,"gen_theta"
        ,"load_p"
        ,"load_q"
        ,"load_v"
        ,"load_theta"
        ,"rho"
        ,"line_status"
        ,"topo_vect"
        ,"time_next_maintenance"
        ,"target_dispatch"
        ,"actual_dispatch"
        ,"current_step"
        ,"max_step" 
        ]

        self.setup_observations()
        self.setup_actions()

    def setup_observations(self):
        # /// Modified observations
        sample_obs, _ = self._gym_env.reset()
        min_obs = {}
        for observation in self.relevantObservations:
            min_obs[observation] = sample_obs[observation]
        flat_obs = self.flatten_observation(min_obs)
        obs_size = flat_obs.shape[0]
        self.observation_space = gym.spaces.Box(low=-np.inf, high=np.inf, shape=(obs_size,), dtype=np.float32)

    def setup_actions(self):
        self.available_actions = []
        num_powerlines =10
        num_generators = 6

        # Get the action space from the Grid2Op environment
        action_space = self._g2op_env.action_space

        # Define discrete actions
        # Action 0: Do nothing
        no_op = action_space({})
        gym_no_op = self._gym_env.action_space.to_gym(no_op)
        self.available_actions.append(gym_no_op)

        #  Open and Close all powerlines
        for line in range(num_powerlines):
            close_line = action_space({"set_line_status":[(line,-1)]})
            gym_close_line = self._gym_env.action_space.to_gym(close_line)
            open_line = action_space({"set_line_status":[(line,1)]})
            gym_open_line = self._gym_env.action_space.to_gym(open_line)
            self.available_actions.append(gym_close_line)
            self.available_actions.append(gym_open_line)

        # Redispatch all generators
        for generator in range(num_generators):
            redispatch_gen = action_space({"redispatch":[(generator,2.5)]})
            gym_redispatch_gen = self._gym_env.action_space.to_gym(redispatch_gen)
            self.available_actions.append(gym_redispatch_gen)

        # Update the action space to Discrete
        self.action_space = gym.spaces.Discrete(len(self.available_actions))


    def reset(self, seed=None):
        obs, info = self._gym_env.reset(seed=seed, options=None)
        min_obs = {}
        for observation in self.relevantObservations:
            min_obs[observation] = obs[observation]
        obs = self.flatten_observation(min_obs)
        return obs, info

    def step(self, action):
        # Retrieve the Gym-formatted action
        gym_action = self.available_actions[action]

        # Pass the action to the environment
        obs, reward, terminated, truncated, info = self._gym_env.step(gym_action)

        min_obs = {}
        for observation in self.relevantObservations:
            min_obs[observation] = obs[observation]
        obs = self.flatten_observation(min_obs)

        # Extract individual rewards
        reward_components = info.get('reward_detail', {})
        info['reward_components'] = reward_components
        
        return obs, reward, terminated, truncated, info

    def render(self):
        return self._gym_env.render()

    def flatten_observation(self, obs):
        obs_list = []
        for key in sorted(obs.keys()):
            obs_component = np.array(obs[key]).flatten()
            obs_list.append(obs_component)
        flat_obs = np.concatenate(obs_list).astype(np.float32)
        return flat_obs

# %% [markdown]
# - #### `Test` the environment

# %%
def test_environment():
    env = Gym2OpEnv()
    obs, info = env.reset(seed=12)
    print("Initial observation shape:", obs.shape)
    print("Initial observation:", obs)

    for _ in range(5):
        action = env.action_space.sample()
        obs, reward, terminated, truncated, info = env.step(action)
        print("Step result:")
        print("Action taken:", action)
        print("Observation shape:", obs.shape)
        print("Reward:", reward)
        print("Terminated:", terminated)
        if terminated or truncated:
            obs, info = env.reset()

if __name__ == "__main__":
    test_environment()
# Out:
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\dtypes\cast.py:1641: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])
# Initial observation shape: (200,)
# Initial observation: [ 0.0000000e+00  0.0000000e+00  0.0000000e+00  0.0000000e+00
#   0.0000000e+00  0.0000000e+00  0.0000000e+00  7.9599998e+01
#   7.8000000e+01  2.0299999e+01  0.0000000e+00  0.0000000e+00
#   7.5894516e+01  1.9370398e+01  7.4134529e+01  2.2987965e+01
#   2.2987965e+01  2.4470367e+01 -1.6485050e+01 -1.3930471e+00
#  -4.0993605e+00 -8.0236607e+00 -8.0236607e+00 -7.6959491e+00
#   0.0000000e+00  1.4210001e+02  1.4210001e+02  2.2000000e+01
#   2.2000000e+01  1.3200001e+01  1.4210001e+02  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  2.3299999e+01
#   8.7300003e+01  4.6599998e+01  7.0999999e+00  1.1700000e+01
#   2.8400000e+01  8.8000002e+00  3.5000000e+00  5.5000000e+00
#   1.2700000e+01  1.5000000e+01  1.5800000e+01  6.1799999e+01
#   3.2400002e+01  4.9000001e+00  8.3000002e+00  1.9799999e+01
#   6.1999998e+00  2.4000001e+00  3.9000001e+00  8.6999998e+00
#   1.0400000e+01 -1.3930471e+00 -4.0993605e+00 -5.1354852e+00
#  -4.4335208e+00 -8.0236607e+00 -9.0087538e+00 -9.0810661e+00
#  -8.6473989e+00 -8.6808910e+00 -8.7638044e+00 -9.6916456e+00
#   1.4210001e+02  1.4210001e+02  1.3873708e+02  1.3948439e+02
#   2.2000000e+01  2.1088869e+01  2.1090616e+01  2.1455412e+01
#   2.1569487e+01  2.1422289e+01  2.0714663e+01  8.0640000e+03
#   0.0000000e+00  3.1787652e-01  3.2880214e-01  2.7300203e-01
#   2.5028309e-01  7.4860901e-01  2.3902652e-01  3.8123316e-01
#   5.9178394e-01  5.1039964e-01  7.6713520e-01  9.6475840e-02
#   3.3880928e-01  3.2805002e-01  4.6724021e-01  4.4041273e-01
#   4.9678454e-01  4.7421613e-01  6.9814813e-01  4.6193391e-01
#   4.1824999e-01  0.0000000e+00  0.0000000e+00  0.0000000e+00
#   0.0000000e+00  0.0000000e+00  0.0000000e+00 -1.0000000e+00
#  -1.0000000e+00 -1.0000000e+00 -1.0000000e+00 -1.0000000e+00
#  -1.0000000e+00 -1.0000000e+00 -1.0000000e+00 -1.0000000e+00
#  -1.0000000e+00 -1.0000000e+00 -1.0000000e+00 -1.0000000e+00
#  -1.0000000e+00 -1.0000000e+00 -1.0000000e+00 -1.0000000e+00
#  -1.0000000e+00 -1.0000000e+00 -1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00]
# Step result:
# Action taken: 26
# Observation shape: (200,)
# Reward: 0.32073068618774414
# Terminated: False
# Step result:
# Action taken: 20
# Observation shape: (200,)
# Reward: 0.31870993971824646
# Terminated: False
# Step result:
# Action taken: 3
# Observation shape: (200,)
# Reward: 0.19666151702404022
# Terminated: False
# Step result:
# Action taken: 6
# Observation shape: (200,)
# Reward: 0.19718579947948456
# Terminated: False
# Step result:
# Action taken: 9
# Observation shape: (200,)
# Reward: 0.19846710562705994
# Terminated: False

# %% [markdown]
# -  #### `Print` observation space and action space

# %%
def test_environment():
    env = Gym2OpEnv()

    # Print the action and observation spaces
    print("Action space:", env.action_space)
    print("Number of actions:", env.action_space.n)
    print("Observation space:", env.observation_space)
    print("Observation shape:", env.observation_space.shape)

    obs, info = env.reset()
    print("Initial observation shape:", obs.shape)
    print("Initial observation:", obs)

    # Sample a random action
    action = env.action_space.sample()
    print("Sampled action index:", action)
    print("Corresponding action:", env.available_actions[action])

    # Take a step
    obs, reward, terminated, truncated, info = env.step(action)
    print("Observation after action:", obs)
    print("Reward received:", reward)
    print("Terminated:", terminated)
    print("Truncated:", truncated)
    print("Info:", info)

# %%
test_environment()

# %% [markdown]
# - #### `Test` the environment

# %%
def main():
    max_steps = 100
    env = Gym2OpEnv()

    print("#####################")
    print("# OBSERVATION SPACE #")
    print("#####################")
    print(env.observation_space)
    print("#####################\n")

    print("#####################")
    print("#   ACTION SPACE    #")
    print("#####################")
    print(env.action_space)
    print("#####################\n\n")

    curr_step = 0
    curr_return = 0

    is_done = False
    obs, info = env.reset()
    print(f"step = {curr_step} (reset):")
    print(f"\t obs = {obs}")
    print(f"\t info = {info}\n\n")

    while not is_done and curr_step < max_steps:
        # Random action
        action = env.action_space.sample()
        obs, reward, terminated, truncated, info = env.step(action)

        curr_step += 1
        curr_return += reward
        is_done = terminated or truncated

        print(f"step = {curr_step}: ")
        print(f"\t obs = {obs}")
        print(f"\t reward = {reward}")
        print(f"\t terminated = {terminated}")
        print(f"\t truncated = {truncated}")
        print(f"\t info = {info}")

        # Checking if action is valid
        is_action_valid = not (info["is_illegal"] or info["is_ambiguous"])
        print(f"\t is action valid = {is_action_valid}")
        if not is_action_valid:
            print(f"\t\t reason = {info['exception']}")
        print("\n")

    print("###########")
    print("# SUMMARY #")
    print("###########")
    print(f"return = {curr_return}")
    print(f"total steps = {curr_step}")
    print("###########")

if __name__ == "__main__":
    main()

# %% [markdown]
# # Implement your agent here

# %%
def train_dqn_agent():
    env = Gym2OpEnv()
    model = DQN("MlpPolicy", env, verbose=1,
            learning_rate=0.0005,
            buffer_size=100000,
            batch_size=32,
            gamma=0.99,
            exploration_fraction=0.1,
            exploration_final_eps=0.02)
    model.learn(total_timesteps=10000)
    model.save("dqn_grid2op_agent")

    # Evaluate the trained model
    obs, _ = env.reset(seed=12)
    for step in range(100):
        action, _states = model.predict(obs)
        obs, reward, done, truncated, info = env.step(action)
        env.render()
        if done:
            print("Episode finished after {} timesteps".format(step + 1))
            break

if __name__ == "__main__":
    train_dqn_agent()
# Out:
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\dtypes\cast.py:1641: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 2.37     |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 47       |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 44       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.5      |
# |    ep_rew_mean      | 1.49     |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 41       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 68       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.5      |
# |    ep_rew_mean      | 1.42     |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 43       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 102      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19     |
# |    ep_rew_mean      | 1.41     |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 45       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 131      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 67.6     |
# |    n_updates        | 7        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.25     |
# |    ep_rew_mean      | 1.35     |
# |    exploration_rate | 0.838    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 45       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 165      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 56.6     |
# |    n_updates        | 16       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.67     |
# |    ep_rew_mean      | 1.46     |
# |    exploration_rate | 0.796    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 47       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 208      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 36.6     |
# |    n_updates        | 26       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.64     |
# |    ep_rew_mean      | 1.52     |
# |    exploration_rate | 0.763    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 47       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 242      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 41.1     |
# |    n_updates        | 35       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.94     |
# |    ep_rew_mean      | 1.67     |
# |    exploration_rate | 0.72     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 49       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 286      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 19.4     |
# |    n_updates        | 46       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.81     |
# |    ep_rew_mean      | 1.66     |
# |    exploration_rate | 0.689    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 49       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 317      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 24.5     |
# |    n_updates        | 54       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.45     |
# |    ep_rew_mean      | 1.87     |
# |    exploration_rate | 0.63     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 53       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 378      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 15.1     |
# |    n_updates        | 69       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.64     |
# |    ep_rew_mean      | 1.86     |
# |    exploration_rate | 0.584    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 55       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 424      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 9.74     |
# |    n_updates        | 80       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.9      |
# |    ep_rew_mean      | 1.97     |
# |    exploration_rate | 0.535    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 58       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 475      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 19.1     |
# |    n_updates        | 93       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 2.21     |
# |    exploration_rate | 0.458    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 62       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 553      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 14.7     |
# |    n_updates        | 113      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 2.21     |
# |    exploration_rate | 0.416    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 61       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 596      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 11.7     |
# |    n_updates        | 123      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 2.48     |
# |    exploration_rate | 0.329    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 65       |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 685      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 10.5     |
# |    n_updates        | 146      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 2.52     |
# |    exploration_rate | 0.277    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 66       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 738      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 7.34     |
# |    n_updates        | 159      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 2.46     |
# |    exploration_rate | 0.243    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 65       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 772      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 7.81     |
# |    n_updates        | 167      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 3.46     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 80       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 1063     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 5.95     |
# |    n_updates        | 240      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 3.75     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 83       |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 1176     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 7.9      |
# |    n_updates        | 268      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 3.87     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 84       |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 1262     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 10.3     |
# |    n_updates        | 290      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.4     |
# |    ep_rew_mean      | 5.19     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 98       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 1633     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.953    |
# |    n_updates        | 383      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.7     |
# |    ep_rew_mean      | 4.97     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 96       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 1649     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 10.3     |
# |    n_updates        | 387      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.2     |
# |    ep_rew_mean      | 5.17     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 97       |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 1769     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 7.3      |
# |    n_updates        | 417      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.6     |
# |    ep_rew_mean      | 4.95     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 95       |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 1781     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 12.7     |
# |    n_updates        | 420      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.3     |
# |    ep_rew_mean      | 6.4      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 108      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 2331     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.22     |
# |    n_updates        | 557      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.6     |
# |    ep_rew_mean      | 6.53     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 108      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 2409     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 7.15     |
# |    n_updates        | 577      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.7     |
# |    ep_rew_mean      | 6.78     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 109      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 2535     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.632    |
# |    n_updates        | 608      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.2     |
# |    ep_rew_mean      | 7.31     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 113      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 2718     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 7.22     |
# |    n_updates        | 654      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 8.28     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 118      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 3034     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 3.53     |
# |    n_updates        | 733      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.8     |
# |    ep_rew_mean      | 8.24     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 116      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 3046     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 13.2     |
# |    n_updates        | 736      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.2     |
# |    ep_rew_mean      | 8.39     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 115      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 3130     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 9.78     |
# |    n_updates        | 757      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.6     |
# |    ep_rew_mean      | 8.8      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 117      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 3306     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 3.88     |
# |    n_updates        | 801      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.2     |
# |    ep_rew_mean      | 9        |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 118      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 3411     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 3.95     |
# |    n_updates        | 827      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.1     |
# |    ep_rew_mean      | 8.93     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 116      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 3423     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 4.16     |
# |    n_updates        | 830      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33       |
# |    ep_rew_mean      | 9.63     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 120      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 3680     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 7.06     |
# |    n_updates        | 894      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.4     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 121      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 3860     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 3.56     |
# |    n_updates        | 939      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34       |
# |    ep_rew_mean      | 9.97     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 119      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 3874     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.728    |
# |    n_updates        | 943      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.3     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 119      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 3986     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 10.2     |
# |    n_updates        | 971      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 120      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 4154     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 7.21     |
# |    n_updates        | 1013     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.6     |
# |    ep_rew_mean      | 10.9     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 122      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 4347     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 3.58     |
# |    n_updates        | 1061     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 39.5     |
# |    ep_rew_mean      | 11.9     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 125      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 4686     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.631    |
# |    n_updates        | 1146     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.5     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 129      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 5017     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 13       |
# |    n_updates        | 1229     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.3     |
# |    ep_rew_mean      | 12.5     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 129      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 5189     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 6.95     |
# |    n_updates        | 1272     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.3     |
# |    ep_rew_mean      | 13.3     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 132      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 5509     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 6.65     |
# |    n_updates        | 1352     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 46       |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 135      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 5859     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 3.86     |
# |    n_updates        | 1439     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.4     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 134      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 5872     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 6.88     |
# |    n_updates        | 1442     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.8     |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 133      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 5925     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.661    |
# |    n_updates        | 1456     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.2     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 133      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 5994     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 3.69     |
# |    n_updates        | 1473     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.7     |
# |    ep_rew_mean      | 13.3     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 133      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 6153     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.25     |
# |    n_updates        | 1513     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.5     |
# |    ep_rew_mean      | 12.4     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 134      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 6381     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.82     |
# |    n_updates        | 1570     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.5     |
# |    ep_rew_mean      | 12.4     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 134      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 6457     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.458    |
# |    n_updates        | 1589     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.2     |
# |    ep_rew_mean      | 13.4     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 137      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 6858     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 6.67     |
# |    n_updates        | 1689     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 46       |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 140      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 7319     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 3.62     |
# |    n_updates        | 1804     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 47.2     |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 143      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 7754     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.605    |
# |    n_updates        | 1913     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 49       |
# |    ep_rew_mean      | 15.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 143      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 7942     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.766    |
# |    n_updates        | 1960     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.6     |
# |    ep_rew_mean      | 16.3     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 146      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 8390     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.497    |
# |    n_updates        | 2072     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.2     |
# |    ep_rew_mean      | 15.9     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 146      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 8428     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.471    |
# |    n_updates        | 2081     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.6     |
# |    ep_rew_mean      | 15.7     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 145      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 8475     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 6.72     |
# |    n_updates        | 2093     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.1     |
# |    ep_rew_mean      | 16.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 145      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 8631     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.402    |
# |    n_updates        | 2132     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.6     |
# |    ep_rew_mean      | 16.1     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 146      |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 8941     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 6.7      |
# |    n_updates        | 2210     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.5     |
# |    ep_rew_mean      | 15.8     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 146      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 9013     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 3.71     |
# |    n_updates        | 2228     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.6     |
# |    ep_rew_mean      | 16.9     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 147      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 9331     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.749    |
# |    n_updates        | 2307     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.9     |
# |    ep_rew_mean      | 17       |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 146      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 9473     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 6.66     |
# |    n_updates        | 2343     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.1     |
# |    ep_rew_mean      | 16.6     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 146      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 9569     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 3.79     |
# |    n_updates        | 2367     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.3     |
# |    ep_rew_mean      | 15.9     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 145      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 9581     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 3.66     |
# |    n_updates        | 2370     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 49.3     |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 144      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 9617     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 3.57     |
# |    n_updates        | 2379     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 47.7     |
# |    ep_rew_mean      | 14.5     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 144      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 9791     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.545    |
# |    n_updates        | 2422     |
# ----------------------------------
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# ...
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)

# %% [markdown]
# - #### `Evaluate` the environment

# %%
def evaluate_agent(model, env, num_episodes=10):
    episode_rewards = []
    reward_sum = 0
    for episode in range(num_episodes):
        obs, _ = env.reset()
        done = False
        total_reward = 0
        while not done:
            action, _states = model.predict(obs, deterministic=True)
            obs, reward, done, _, info = env.step(action)
            total_reward += reward
        episode_rewards.append(total_reward)
        print(f"Episode {episode + 1}: Total Reward = {total_reward}")
        reward_sum += total_reward
    print(f"Average Reward:", reward_sum/num_episodes)
    print(f"Total reward:",reward_sum)
    return episode_rewards,(reward_sum/num_episodes)

# %% [markdown]
# - #### `Run` the evaluation function

# %%
if __name__ == "__main__":
    # Initialize the environment and model
    env = Gym2OpEnv()
    model = DQN("MlpPolicy", env, verbose=1)
    
    # Load the trained model (optional)
    model = DQN.load("dqn_grid2op_agent", env=env)
    
    # Evaluate the trained model
    num_evaluation_episodes = 20
    rewards,average = evaluate_agent(model, env, num_episodes=num_evaluation_episodes)
# Out:
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\dtypes\cast.py:1641: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Episode 1: Total Reward = 268.1452095210552
# Episode 2: Total Reward = 1567.3029865175486
# Episode 3: Total Reward = 870.7465864121914
# Episode 4: Total Reward = 2347.699774160981
# Episode 5: Total Reward = 1959.4963975399733
# Episode 6: Total Reward = 1056.5338168293238
# Episode 7: Total Reward = 433.46572428941727
# Episode 8: Total Reward = 366.2164732962847
# Episode 9: Total Reward = 281.2962398827076
# Episode 10: Total Reward = 382.5044099390507
# Episode 11: Total Reward = 1038.3458653390408
# Episode 12: Total Reward = 372.26637513935566
# Episode 13: Total Reward = 1625.9882570654154
# Episode 14: Total Reward = 282.7306272983551
# Episode 15: Total Reward = 237.07497850060463
# Episode 16: Total Reward = 366.49944157898426
# Episode 17: Total Reward = 1062.5586376786232
# Episode 18: Total Reward = 887.1421447843313
# Episode 19: Total Reward = 181.8778905570507
# Episode 20: Total Reward = 183.82561320066452
# Average Reward: 788.5858724765479
# Total reward: 15771.71744953096

# %% [markdown]
# - #### `Visualise` the results

# %%
def plot_rewards(episode_rewards):
    plt.figure(figsize=(12, 6))
    plt.plot(range(1, len(episode_rewards) + 1), episode_rewards, marker='o')
    plt.title('Agent Performance Over Episodes')
    plt.xlabel('Episode')
    plt.ylabel('Total Reward')
    plt.grid(True)
    plt.show()

# %%
# call plot function
plot_rewards(rewards)

#1:173,776
#2:175.198225319385
#3:175.198

# %% [markdown]
# - ### `Reward Shaping` to encourage agent make better decisions

# %%
from grid2op.Reward import BaseReward

class CustomTrainingReward(BaseReward):
    def __init__(self):
        super().__init__()
    
    def initialize(self, env):
        super().initialize(env)
    
    def reset(self, env):
        super().reset(env)
    
    def __call__(self, action, env, has_error, is_done, is_illegal, is_ambiguous):
        # Compute the custom reward
        reward = 0.0

        # Access the current observation
        current_obs = env.current_obs

        # Get the maximum line loading (rho)
        max_rho = current_obs.rho.max()

        # Penalize line overloads
        if max_rho > 1.0:
            overload_amount = max_rho - 1.0
            reward -= overload_amount * 10  # Penalty proportional to overload

        # Reward safe operation
        elif max_rho < 0.8:
            reward += 1.0  # Reward for keeping lines below 80% capacity

        # Create a "do nothing" action
        do_nothing_action = env.action_space()

        # Penalize unnecessary actions to encourage efficiency
        if not action == do_nothing_action and not is_illegal:
            reward -= 0.1  # Small penalty for taking an action

        # Penalize illegal actions
        if is_illegal:
            reward -= 5.0  # Heavy penalty for illegal actions

        # Additional penalties or rewards based on other parameters
        if has_error:
            reward -= 10.0  # Penalty for errors

        if is_done and has_error:
            reward -= 20.0  # Penalty if the episode ends due to failure

        return reward

# %%
class Gym2OpEnvRS(gym.Env):
    def __init__(self, seed=None, training =True):
        super().__init__()
        self.training = training # Indicates whether we're training or evaluating
        self.seed_value = seed

        self._backend = LightSimBackend()
        self._env_name = "l2rpn_case14_sandbox"  # DO NOT CHANGE

        action_class = PlayableAction
        observation_class = CompleteObservation
       
        # If training use custom reward class else use combined reward
        if self.training:
            reward_class = CustomTrainingReward
        else:
            reward_class = CombinedScaledReward

      
        # DO NOT CHANGE Parameters
        p = Parameters()
        p.MAX_SUB_CHANGED = 4
        p.MAX_LINE_STATUS_CHANGED = 4


        # Make grid2op env
        self._g2op_env = grid2op.make(
            self._env_name,
            backend=self._backend,
            test=False,
            action_class=action_class,
            observation_class=observation_class,
            reward_class=reward_class,
            param=p,
        )

        # Set the seed for the Grid2Op environment
        if self.seed_value is not None:
            self._g2op_env.seed(seed_value)


        # Conditionally set up combined reward components
        if not self.training:
            # Only add reward components when not training
            cr = self._g2op_env.get_reward_instance()
            cr.addReward("N1", N1Reward(), 1.0)
            cr.addReward("L2RPN", L2RPNReward(), 1.0)
            cr.initialize(self._g2op_env)

        self.relevantObservations = [
        "minute_of_hour"
        ,"gen_p"
        ,"gen_q"
        ,"gen_v"
        ,"gen_theta"
        ,"load_p"
        ,"load_q"
        ,"load_v"
        ,"load_theta"
        ,"rho"
        ,"line_status"
        ,"topo_vect"
        ,"time_next_maintenance"
        ,"target_dispatch"
        ,"actual_dispatch"
        ,"current_step"
        ,"max_step" 
        ]

        self._gym_env = gym_compat.GymEnv(self._g2op_env)

        self.setup_observations()
        self.setup_actions()

    def setup_observations(self):
        # Flatten the observation space
        sample_obs, _ = self._gym_env.reset()
        min_obs = {}
        for observation in self.relevantObservations:
            min_obs[observation] = sample_obs[observation]
        flat_obs = self.flatten_observation(min_obs)
        obs_size = flat_obs.shape[0]
        self.observation_space = gym.spaces.Box(low=-np.inf, high=np.inf, shape=(obs_size,), dtype=np.float32)

    def setup_actions(self):
        self.available_actions = []
        num_powerlines =10
        num_generators = 6

        # Get the action space from the Grid2Op environment
        action_space = self._g2op_env.action_space

        # Define discrete actions
        # Action 0: Do nothing
        no_op = action_space({})
        gym_no_op = self._gym_env.action_space.to_gym(no_op)
        self.available_actions.append(gym_no_op)

         #Open and Close all powerlines
        for line in range(num_powerlines):
            close_line = action_space({"set_line_status":[(line,-1)]})
            gym_close_line = self._gym_env.action_space.to_gym(close_line)
            open_line = action_space({"set_line_status":[(line,1)]})
            gym_open_line = self._gym_env.action_space.to_gym(open_line)
            self.available_actions.append(gym_close_line)
            self.available_actions.append(gym_open_line)

        # Redispatch all generators
        for generator in range(num_generators):
            redispatch_gen = action_space({"redispatch":[(generator,2.5)]})
            gym_redispatch_gen = self._gym_env.action_space.to_gym(redispatch_gen)
            self.available_actions.append(gym_redispatch_gen)

        # Update the action space to Discrete
        self.action_space = gym.spaces.Discrete(len(self.available_actions))


    def reset(self, seed=None):
        if seed is not None:
            self.seed_value = seed

        obs, info = self._gym_env.reset(seed=seed, options=None)
        min_obs = {}
        for observation in self.relevantObservations:
            min_obs[observation] = obs[observation]
        obs = self.flatten_observation(min_obs)
        return obs, info

    def step(self, action):
        # Retrieve the Gym-formatted action
        gym_action = self.available_actions[action]

        # Pass the action to the environment
        obs, reward, terminated, truncated, info = self._gym_env.step(gym_action)

        min_obs = {}
        for observation in self.relevantObservations:
            min_obs[observation] = obs[observation]
        obs = self.flatten_observation(min_obs)

        # Extract individual rewards
        reward_components = info.get('reward_detail', {})
        info['reward_components'] = reward_components
        
        return obs, reward, terminated, truncated, info

    def render(self, mode='human'):
        return self._gym_env.render()

    def flatten_observation(self, obs):
        obs_list = []
        for key in sorted(obs.keys()):
            obs_component = np.array(obs[key]).flatten()
            obs_list.append(obs_component)
        flat_obs = np.concatenate(obs_list).astype(np.float32)
        return flat_obs

# %%
def test_environment():
    env = Gym2OpEnvRS(training= True)
    obs, info = env.reset()
    print("Initial observation shape:", obs.shape)
    print("Initial observation:", obs)

    for _ in range(5):
        action = env.action_space.sample()
        obs, reward, terminated, truncated, info = env.step(action)
        print("Step result:")
        print("Action taken:", action)
        print("Observation shape:", obs.shape)
        print("Reward:", reward)
        print("Terminated:", terminated)
        if terminated or truncated:
            obs, info = env.reset()

if __name__ == "__main__":
    test_environment()
# Out:
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\dtypes\cast.py:1641: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Reward\rewardHelper.py:131: DeprecationWarning: The 'warn' method is deprecated, use 'warning' instead
#   self.logger.warn(f"Reward \"{reward_func.__name__}\" does not support the logger feature. Error was : {exc_}")
# Initial observation shape: (200,)
# Initial observation: [ 0.0000000e+00  0.0000000e+00  0.0000000e+00  0.0000000e+00
#   0.0000000e+00  0.0000000e+00  0.0000000e+00  7.2599998e+01
#   7.0400002e+01  4.0200001e+01  0.0000000e+00  0.0000000e+00
#   6.8696854e+01  1.7485798e+01  7.4705780e+01  2.1165297e+01
#   2.1165297e+01  2.4502893e+01 -1.6299576e+01 -1.3140136e+00
#  -4.2290854e+00 -5.7845726e+00 -5.7845726e+00 -6.7216878e+00
#   0.0000000e+00  1.4210001e+02  1.4210001e+02  2.2000000e+01
#   2.2000000e+01  1.3200001e+01  1.4210001e+02  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  2.2299999e+01
#   8.8099998e+01  4.5299999e+01  7.0999999e+00  1.1800000e+01
#   2.8400000e+01  8.8000002e+00  3.5000000e+00  5.5999999e+00
#   1.2800000e+01  1.4700000e+01  1.5500000e+01  6.0900002e+01
#   3.1799999e+01  5.0000000e+00  8.1999998e+00  1.9900000e+01
#   6.3000002e+00  2.5000000e+00  3.9000001e+00  9.0000000e+00
#   1.0500000e+01 -1.3140136e+00 -4.2290854e+00 -4.6067080e+00
#  -3.8280022e+00 -5.7845726e+00 -7.8107519e+00 -7.6939945e+00
#  -6.8330231e+00 -6.5164771e+00 -6.6597929e+00 -8.0698690e+00
#   1.4210001e+02  1.4210001e+02  1.3909193e+02  1.3988472e+02
#   2.2000000e+01  2.1053822e+01  2.1054342e+01  2.1429468e+01
#   2.1565094e+01  2.1406811e+01  2.0686430e+01  8.0640000e+03
#   0.0000000e+00  3.0028692e-01  2.8436854e-01  2.9344550e-01
#   2.2086433e-01  6.2145865e-01  1.7478840e-01  4.2095566e-01
#   6.9296783e-01  5.2938831e-01  8.1175393e-01  1.5518582e-01
#   2.8588703e-01  4.0521336e-01  5.1913333e-01  4.9740395e-01
#   4.2645040e-01  3.9033398e-01  3.9155626e-01  4.6254796e-01
#   3.6133605e-01  0.0000000e+00  0.0000000e+00  0.0000000e+00
#   0.0000000e+00  0.0000000e+00  0.0000000e+00 -1.0000000e+00
#  -1.0000000e+00 -1.0000000e+00 -1.0000000e+00 -1.0000000e+00
#  -1.0000000e+00 -1.0000000e+00 -1.0000000e+00 -1.0000000e+00
#  -1.0000000e+00 -1.0000000e+00 -1.0000000e+00 -1.0000000e+00
#  -1.0000000e+00 -1.0000000e+00 -1.0000000e+00 -1.0000000e+00
#  -1.0000000e+00 -1.0000000e+00 -1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00]
# Step result:
# Action taken: 19
# Observation shape: (200,)
# Reward: -7.328580713272094
# Terminated: False
# Step result:
# Action taken: 3
# Observation shape: (200,)
# Reward: -7.228437757492065
# Terminated: False
# Step result:
# Action taken: 14
# Observation shape: (200,)
# Reward: -37.22843775749207
# Terminated: True
# Step result:
# Action taken: 3
# Observation shape: (200,)
# Reward: -2.172969675064087
# Terminated: False
# Step result:
# Action taken: 8
# Observation shape: (200,)
# Reward: -2.178063488006592
# Terminated: False

# %% [markdown]
# - ### `Implementing a new exploration strategy` (Boltzmann Exploration)

# %%
class BoltzmannPolicy(DQNPolicy):
    def __init__(self, *args, temperature=1.0, **kwargs):
        super(BoltzmannPolicy, self).__init__(*args, **kwargs)
        self.temperature = temperature

    def _predict(self, obs, deterministic=False):
        q_values = self.q_net(obs)
        if deterministic:
            # Exploit: choose action with highest Q-value
            actions = q_values.argmax(dim=1)
        else:
            # Explore: sample actions using Boltzmann distribution
            probabilities = th.softmax(q_values / self.temperature, dim=1)
            actions = probabilities.multinomial(num_samples=1).squeeze(1)
        return actions

# %% [markdown]
# - ### `DQN` Agent

# %%
def train_dqn_agent():
    env = Gym2OpEnvRS(training=True) # Initialise env with seed

    model = DQN(policy="MlpPolicy",
            env=env,
            learning_rate=1e-4,
            buffer_size=100000,
            learning_starts=1000,
            batch_size=32,
            tau=1.0,
            gamma=0.99,
            train_freq=4,
            gradient_steps=1,
            verbose=1,
            target_update_interval=1000,
            # policy_kwargs={'temperature': 1.0},
        )
    
    model.learn(total_timesteps=10000)
    model.save("dqn_boltzmann_agent")

    # Evaluate the trained model
    obs, _ = env.reset()
    for step in range(100):
        action, _states = model.predict(obs)
        obs, reward, done, truncated, info = env.step(action)
        env.render()
        if done:
            print("Episode finished after {} timesteps".format(step + 1))
            break

if __name__ == "__main__":
    train_dqn_agent()
# Out:
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\dtypes\cast.py:1641: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Reward\rewardHelper.py:131: DeprecationWarning: The 'warn' method is deprecated, use 'warning' instead
#   self.logger.warn(f"Reward \"{reward_func.__name__}\" does not support the logger feature. Error was : {exc_}")
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | -39.5    |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 94       |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 47       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | -40.6    |
# |    exploration_rate | 0.891    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 123      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 115      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | -40.9    |
# |    exploration_rate | 0.867    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 105      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 140      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | -44.2    |
# |    exploration_rate | 0.827    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 105      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 182      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | -44.8    |
# |    exploration_rate | 0.803    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 96       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 207      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | -42.9    |
# |    exploration_rate | 0.769    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 96       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 243      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.89     |
# |    ep_rew_mean      | -43.9    |
# |    exploration_rate | 0.737    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 95       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 277      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.97     |
# |    ep_rew_mean      | -43      |
# |    exploration_rate | 0.697    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 96       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 319      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | -44.8    |
# |    exploration_rate | 0.628    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 104      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 392      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | -44.8    |
# |    exploration_rate | 0.58     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 105      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 442      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | -44.1    |
# |    exploration_rate | 0.529    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 107      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 496      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | -43.9    |
# |    exploration_rate | 0.489    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 108      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 538      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | -43.6    |
# |    exploration_rate | 0.461    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 105      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 567      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | -43.5    |
# |    exploration_rate | 0.396    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 108      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 636      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | -43.2    |
# |    exploration_rate | 0.359    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 107      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 675      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | -42.7    |
# |    exploration_rate | 0.314    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 107      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 722      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | -42.8    |
# |    exploration_rate | 0.287    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 106      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 751      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | -42.3    |
# |    exploration_rate | 0.228    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 108      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 813      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | -42.4    |
# |    exploration_rate | 0.198    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 106      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 844      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | -42.7    |
# |    exploration_rate | 0.17     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 105      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 874      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | -42.9    |
# |    exploration_rate | 0.143    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 104      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 902      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | -43      |
# |    exploration_rate | 0.114    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 102      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 933      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | -43.1    |
# |    exploration_rate | 0.051    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 105      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 999      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | -42.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 114      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 1171     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 131      |
# |    n_updates        | 42       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.2     |
# |    ep_rew_mean      | -40.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 141      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 1617     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 54.4     |
# |    n_updates        | 154      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.9     |
# |    ep_rew_mean      | -35.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 196      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 2735     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 23.8     |
# |    n_updates        | 433      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30       |
# |    ep_rew_mean      | -32.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 206      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 3117     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 10.1     |
# |    n_updates        | 529      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 39.1     |
# |    ep_rew_mean      | -25.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 228      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 4052     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 12       |
# |    n_updates        | 762      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 46.2     |
# |    ep_rew_mean      | -23.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 242      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 4800     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.08     |
# |    n_updates        | 949      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.4     |
# |    ep_rew_mean      | -18.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 252      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 5545     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 17.5     |
# |    n_updates        | 1136     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.2     |
# |    ep_rew_mean      | -16.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 258      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 6067     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.59     |
# |    n_updates        | 1266     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 63.4     |
# |    ep_rew_mean      | -12.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 262      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 6616     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.58     |
# |    n_updates        | 1403     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66       |
# |    ep_rew_mean      | -11.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 262      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 6916     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.457    |
# |    n_updates        | 1478     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66       |
# |    ep_rew_mean      | -10.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 260      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 6993     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.41     |
# |    n_updates        | 1498     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.8     |
# |    ep_rew_mean      | -8.84    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 261      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 7322     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.29     |
# |    n_updates        | 1580     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 70.9     |
# |    ep_rew_mean      | -8.11    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 260      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 7589     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.367    |
# |    n_updates        | 1647     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75.5     |
# |    ep_rew_mean      | -4.76    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 261      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 8091     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.4      |
# |    n_updates        | 1772     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.3     |
# |    ep_rew_mean      | -3.41    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 264      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 8597     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.563    |
# |    n_updates        | 1899     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.2     |
# |    ep_rew_mean      | -1.77    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 262      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 8856     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.683    |
# |    n_updates        | 1963     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.8     |
# |    ep_rew_mean      | 2.62     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 263      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 9458     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.266    |
# |    n_updates        | 2114     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | 4.1      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 261      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 9775     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.248    |
# |    n_updates        | 2193     |
# ----------------------------------
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\grid2op\Environment\environment.py:1415: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   rgb_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8).reshape(self._viewer.height, self._viewer.width, 3)
# Episode finished after 77 timesteps

# %% [markdown]
# - #### `Run` the evaluation function

# %%
if __name__ == "__main__":
    # Initialize the environment and model
    eval_env = Gym2OpEnvRS(training=False)

    model = DQN(policy=BoltzmannPolicy,
            env=eval_env,
            learning_rate=1e-4,
            buffer_size=100000,
            learning_starts=1000,
            batch_size=32,
            tau=1.0,
            gamma=0.99,
            train_freq=4,
            gradient_steps=1,
            verbose=1,
            target_update_interval=1000,
            policy_kwargs={'temperature': 1.0},
        )
    
    # Load the trained model
    model = DQN.load("dqn_boltzmann_agent", env=eval_env)
    
    # Evaluate the trained model
    num_evaluation_episodes = 20
    rewards = evaluate_agent(model, eval_env, num_episodes=num_evaluation_episodes)
    # plot_rewards(rewards)
# Out:
# c:\Users\widas\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\dtypes\cast.py:1641: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Episode 1: Total Reward = 140.92338702082634
# Episode 2: Total Reward = 267.9231905043125
# Episode 3: Total Reward = 264.6864255666733
# Episode 4: Total Reward = 124.69982361793518
# Episode 5: Total Reward = 125.18820042908192
# Episode 6: Total Reward = 136.10066410899162
# Episode 7: Total Reward = 176.36883473023772
# Episode 8: Total Reward = 110.89571616053581
# Episode 9: Total Reward = 134.37286865711212
# Episode 10: Total Reward = 130.76201310753822
# Episode 11: Total Reward = 119.45418721437454
# Episode 12: Total Reward = 212.88587799668312
# Episode 13: Total Reward = 376.59477953612804
# Episode 14: Total Reward = 135.19713270664215
# Episode 15: Total Reward = 174.84482344985008
# Episode 16: Total Reward = 172.94037133455276
# Episode 17: Total Reward = 363.56818951666355
# Episode 18: Total Reward = 103.8522452712059
# Episode 19: Total Reward = 205.0169439613819
# Episode 20: Total Reward = 209.0882394015789
# Average Reward: 184.26819571461527
# Total reward: 3685.3639142923057
